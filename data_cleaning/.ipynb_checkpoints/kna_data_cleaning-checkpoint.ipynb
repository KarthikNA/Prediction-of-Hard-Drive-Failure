# %%
import pandas as pd
import numpy as np

# %%
from os import listdir
from os.path import isfile, join

# %% [markdown]
# # set file path before execution
# # filepath should point to the directory where all the csv or data files located

# %%
filepath = "../../drive_stats_2019_Q1"

# list all the valid file names
files = [f for f in listdir(filepath) if isfile(join(filepath, f))]
files = [f for f in files if "csv" in f and f.startswith("201")]
len(files)
# Out:
# 90

# %%
# determine all the columns that have to be dropped by default
def drop_column_names():
    data = pd.read_csv(filepath +"/2019-01-01.csv")
    drop_columns = []
    for i in data.columns:
        if "normalized" in i:
            drop_columns.append(i)     
    return drop_columns

# %%
# columns that have to be dropped
drop_names = drop_column_names()

# %%
# put all the dataframes into a list 
master_df_list = []

# %%
# iterate over each file and drop the unwanted columns
for file_name in files:
    data = pd.read_csv(filepath + "/" +file_name)
    data.drop(drop_names, axis = 1, inplace=True)
    master_df_list.append(data.copy())
    print("{} added to master_list".format(file_name))
# Out:
# 2019-01-22.csv added to master_list
# 2019-03-27.csv added to master_list
# 2019-03-26.csv added to master_list
# 2019-01-23.csv added to master_list
# 2019-01-09.csv added to master_list
# 2019-01-21.csv added to master_list
# 2019-03-18.csv added to master_list
# 2019-03-24.csv added to master_list
# 2019-03-30.csv added to master_list
# 2019-03-31.csv added to master_list
# 2019-03-25.csv added to master_list
# 2019-03-19.csv added to master_list
# 2019-01-20.csv added to master_list
# 2019-01-08.csv added to master_list
# 2019-01-24.csv added to master_list
# 2019-01-30.csv added to master_list
# 2019-01-18.csv added to master_list
# 2019-03-21.csv added to master_list
# 2019-03-09.csv added to master_list
# 2019-03-08.csv added to master_list
# 2019-03-20.csv added to master_list
# 2019-01-19.csv added to master_list
# 2019-01-31.csv added to master_list
# 2019-01-25.csv added to master_list
# 2019-01-27.csv added to master_list
# 2019-03-22.csv added to master_list
# 2019-03-23.csv added to master_list
# 2019-01-26.csv added to master_list
# 2019-02-04.csv added to master_list
# 2019-02-10.csv added to master_list
# 2019-02-11.csv added to master_list
# 2019-02-05.csv added to master_list
# 2019-02-13.csv added to master_list
# 2019-02-07.csv added to master_list
# 2019-02-06.csv added to master_list
# 2019-02-12.csv added to master_list
# 2019-02-16.csv added to master_list
# 2019-02-02.csv added to master_list
# 2019-02-03.csv added to master_list
# 2019-02-17.csv added to master_list
# 2019-02-01.csv added to master_list
# 2019-02-15.csv added to master_list
# 2019-02-14.csv added to master_list
# 2019-02-28.csv added to master_list
# 2019-02-25.csv added to master_list
# 2019-02-19.csv added to master_list
# 2019-02-18.csv added to master_list
# 2019-02-24.csv added to master_list
# 2019-02-26.csv added to master_list
# 2019-02-27.csv added to master_list
# 2019-02-23.csv added to master_list
# 2019-02-22.csv added to master_list
# 2019-02-08.csv added to master_list
# 2019-02-20.csv added to master_list
# 2019-02-21.csv added to master_list
# 2019-02-09.csv added to master_list
# 2019-01-17.csv added to master_list
# 2019-01-03.csv added to master_list
# 2019-03-12.csv added to master_list
# 2019-03-06.csv added to master_list
# 2019-03-07.csv added to master_list
# 2019-03-13.csv added to master_list
# 2019-01-02.csv added to master_list
# 2019-01-16.csv added to master_list
# 2019-01-28.csv added to master_list
# 2019-01-14.csv added to master_list
# 2019-03-05.csv added to master_list
# 2019-03-11.csv added to master_list
# 2019-03-10.csv added to master_list
# 2019-03-04.csv added to master_list
# 2019-01-15.csv added to master_list
# 2019-01-01.csv added to master_list
# 2019-01-29.csv added to master_list
# 2019-01-05.csv added to master_list
# 2019-01-11.csv added to master_list
# 2019-03-14.csv added to master_list
# 2019-03-28.csv added to master_list
# 2019-03-29.csv added to master_list
# 2019-03-15.csv added to master_list
# 2019-03-01.csv added to master_list
# 2019-01-10.csv added to master_list
# 2019-01-04.csv added to master_list
# 2019-01-12.csv added to master_list
# 2019-01-06.csv added to master_list
# 2019-03-17.csv added to master_list
# 2019-03-03.csv added to master_list
# 2019-03-02.csv added to master_list
# 2019-03-16.csv added to master_list
# 2019-01-07.csv added to master_list
# 2019-01-13.csv added to master_list

# %%
# generate a master data frame to have all the data
master_df = pd.concat(master_df_list)
master_df.shape
# Out:
# (9577046, 67)

# %%
# determine the count of each model in entire dataset
models_count = master_df["model"]
models_count = models_count.value_counts().to_frame()
models_count.columns = ["count"]
models_count['name'] = models_count.index
models_count.reset_index(drop=True)
models_count.shape
# Out:
# (49, 2)

# %%
# determine the failure_count of each model in entire dataset
failure_counts = master_df[master_df["failure"]==1].groupby(["model"]).agg({'model':'count'})
failure_counts.columns = ["failed_count"]
failure_counts['name'] = failure_counts.index
failure_counts = failure_counts.reset_index(drop=True)
failure_counts.shape
# Out:
# (20, 2)

# %%
# determine the no_failure_count of each model in entire dataset
no_failure_counts = master_df[master_df["failure"]==0].groupby(["model"]).agg({'model':'count'})
no_failure_counts.columns = ["no_failed_count"]
no_failure_counts['name'] = no_failure_counts.index
no_failure_counts = no_failure_counts.reset_index(drop=True)
no_failure_counts.shape
# Out:
# (49, 2)

# %%
# combine no_failure_counts and failure_counts into one df
merged_level_1 = pd.merge(no_failure_counts, failure_counts, left_on='name', right_on='name', how="left")
merged_level_1
# Out:
#     no_failed_count                                 name  failed_count
# 0               540                          DELLBOSS VD           NaN
# 1              3117                 HGST HDS5C4040ALE630           NaN
# 2            313381                 HGST HMS5C4040ALE640           2.0
# 3           1172813                 HGST HMS5C4040BLE640          11.0
# 4                90                 HGST HMS5C4040BLE641           NaN
# 5              1245                 HGST HUH721010ALE600           NaN
# 6             14039                 HGST HUH721212ALE600           1.0
# 7            259745                 HGST HUH721212ALN604           4.0
# 8             93595                 HGST HUH728080ALE600           3.0
# 9              2598                 HGST HUS726040ALE610           NaN
# 10              626              Hitachi HDS5C4040ALE630           NaN
# 11               29              Hitachi HDS724040ALE640           NaN
# 12           108552                        ST10000NM0086           3.0
# 13               90                       ST1000LM024 HN           NaN
# 14          2954845                        ST12000NM0007         180.0
# 15               24                        ST250LM004 HN           NaN
# 16               42                          ST3160316AS           NaN
# 17               14                          ST3160318AS           NaN
# 18               85                           ST320LT007           NaN
# 19          1989322                          ST4000DM000         107.0
# 20             4848                          ST4000DM005           NaN
# 21            50607                        ST500LM012 HN          12.0
# 22               82                           ST500LM021           NaN
# 23            14470                           ST500LM030           9.0
# 24             1113                          ST6000DM001           NaN
# 25              180                          ST6000DM004           NaN
# 26           135831                          ST6000DX000           1.0
# 27           888712                          ST8000DM002          29.0
# 28              272                          ST8000DM004           1.0
# 29             2250                          ST8000DM005           NaN
# 30          1294393                         ST8000NM0055          58.0
# 31              265  Seagate BarraCuda SSD ZA2000CM10002           NaN
# 32             1564   Seagate BarraCuda SSD ZA500CM10002           NaN
# 33              834                      TOSHIBA HDWE160           NaN
# 34             1798                      TOSHIBA HDWF180           NaN
# 35            12662                  TOSHIBA MD04ABA400V           NaN
# 36             4050                  TOSHIBA MD04ABA500V           NaN
# 37           109403                  TOSHIBA MG07ACA14TA           1.0
# 38            46955                   TOSHIBA MQ01ABF050          14.0
# 39            32621                  TOSHIBA MQ01ABF050M           3.0
# 40              251                       WDC WD1600AAJS           NaN
# 41               88                       WDC WD2500AAJS           NaN
# 42                3                       WDC WD3200AAJS           NaN
# 43               29                       WDC WD3200BEKX           NaN
# 44               94                         WDC WD40EFRX           NaN
# 45              982                       WDC WD5000BPKT           NaN
# 46             4918                       WDC WD5000LPCX           2.0
# 47            22013                       WDC WD5000LPVX           2.0
# 48            30522                         WDC WD60EFRX           1.0

# %%
# combine models_count and failure_counts into one df
merged_level_2 = pd.merge(models_count, merged_level_1, left_on='name', right_on='name', how="left")
merged_level_2 = merged_level_2.fillna(0)
merged_level_2["failed_count"] = merged_level_2["failed_count"].astype('int32')
merged_level_2 = merged_level_2.sort_values(by='failed_count', ascending=False)
merged_level_2
# Out:
#       count                                 name  no_failed_count  \
# 0   2955025                        ST12000NM0007          2954845
# 1   1989429                          ST4000DM000          1989322
# 2   1294451                         ST8000NM0055          1294393
# 4    888741                          ST8000DM002           888712
# 12    46969                   TOSHIBA MQ01ABF050            46955
# 11    50619                        ST500LM012 HN            50607
# 3   1172824                 HGST HMS5C4040BLE640          1172813
# 16    14479                           ST500LM030            14470
# 6    259749                 HGST HUH721212ALN604           259745
# 9    108555                        ST10000NM0086           108552
# 10    93598                 HGST HUH728080ALE600            93595
# 13    32624                  TOSHIBA MQ01ABF050M            32621
# 15    22015                       WDC WD5000LPVX            22013
# 5    313383                 HGST HMS5C4040ALE640           313381
# 19     4920                       WDC WD5000LPCX             4918
# 17    14040                 HGST HUH721212ALE600            14039
# 14    30523                         WDC WD60EFRX            30522
# 8    109404                  TOSHIBA MG07ACA14TA           109403
# 7    135832                          ST6000DX000           135831
# 33      273                          ST8000DM004              272
# 46       24                        ST250LM004 HN               24
# 45       29                       WDC WD3200BEKX               29
# 44       29              Hitachi HDS724040ALE640               29
# 43       42                          ST3160316AS               42
# 47       14                          ST3160318AS               14
# 34      265  Seagate BarraCuda SSD ZA2000CM10002              265
# 41       85                           ST320LT007               85
# 40       88                       WDC WD2500AAJS               88
# 39       90                 HGST HMS5C4040BLE641               90
# 38       90                       ST1000LM024 HN               90
# 37       94                         WDC WD40EFRX               94
# 36      180                          ST6000DM004              180
# 35      251                       WDC WD1600AAJS              251
# 42       82                           ST500LM021               82
# 24     2250                          ST8000DM005             2250
# 32      540                          DELLBOSS VD              540
# 31      626              Hitachi HDS5C4040ALE630              626
# 30      834                      TOSHIBA HDWE160              834
# 29      982                       WDC WD5000BPKT              982
# 28     1113                          ST6000DM001             1113
# 27     1245                 HGST HUH721010ALE600             1245
# 26     1564   Seagate BarraCuda SSD ZA500CM10002             1564
# 25     1798                      TOSHIBA HDWF180             1798
# 23     2598                 HGST HUS726040ALE610             2598
# 22     3117                 HGST HDS5C4040ALE630             3117
# 21     4050                  TOSHIBA MD04ABA500V             4050
# 20     4848                          ST4000DM005             4848
# 18    12662                  TOSHIBA MD04ABA400V            12662
# 48        3                       WDC WD3200AAJS                3
#
#     failed_count
# 0            180
# 1            107
# 2             58
# 4             29
# 12            14
# 11            12
# 3             11
# 16             9
# 6              4
# 9              3
# 10             3
# 13             3
# 15             2
# 5              2
# 19             2
# 17             1
# 14             1
# 8              1
# 7              1
# 33             1
# 46             0
# 45             0
# 44             0
# 43             0
# 47             0
# 34             0
# 41             0
# 40             0
# 39             0
# 38             0
# 37             0
# 36             0
# 35             0
# 42             0
# 24             0
# 32             0
# 31             0
# 30             0
# 29             0
# 28             0
# 27             0
# 26             0
# 25             0
# 23             0
# 22             0
# 21             0
# 20             0
# 18             0
# 48             0

# %%
merged_level_2.to_csv(r'base_stats.csv', index = False)

# %% [markdown]
# # Analysis of Model 1 EXPERIMENTING -

# %%
model_1 = master_df[master_df["model"] == "ST12000NM0007"]

# %%
# drop all columns that are only NaN
model_1 = model_1.dropna(axis=1, how='all') # 67 to 27 column reduction
model_1

# %%
cols = model_1.select_dtypes([np.number]).columns
std = model_1[cols].std()
cols_to_drop = std[std==0].index
cols_to_drop
# df.drop(cols_to_drop, axis=1)

# %%
# returns the total number of null values in each column
# model_1.isnull().sum(axis = 0)

# %%
# returns the column names with atleast one empty NaN value
# model_1.columns[model_1.isna().any()].tolist()

# %%
# model_1[model_1.isnull().any(axis=1)]

# %%
# drops all rows with even one NaN value
print(model_1.shape)
model_1 = model_1.dropna()
print(model_1.shape)

# %%
# find all columns that are filled with the same value
columns_with_same_values = model_1.columns[model_1.nunique() <= 1].tolist()
# do not remove the columns 'model' and 'capacity_bytes'
columns_with_same_values.remove('model')
columns_with_same_values.remove('capacity_bytes')
columns_with_same_values

# %%
print(model_1.shape)
model_1 = model_1.drop(columns_with_same_values, axis=1)
print(model_1.shape)

# %%
model_1 = model_1.sort_values(['serial_number', 'date'], ascending=[True, True])

# %% [markdown]
# # FINAL CLEANING CODE

# %%
# set the model name here 
model_name = "ST12000NM0007"

# %%
# data cleaning operations
def data_cleaning(model_name):
    model_1 = master_df[master_df["model"] == model_name]
    
    # drop all columns that are only NaN
    model_1 = model_1.dropna(axis=1, how='all')
    print("initial column drop done")
    
    # drops all rows with even one NaN value
    model_1 = model_1.dropna()
    print("initial row drop done")
    
    # find all columns that are filled with the same value and drop them
    columns_with_same_values = model_1.columns[model_1.nunique() <= 1].tolist()
    
    # do not remove the columns 'model' and 'capacity_bytes'
    columns_with_same_values.remove('model')
    columns_with_same_values.remove('capacity_bytes')
    model_1 = model_1.drop(columns_with_same_values, axis=1)
    print("repeating cloumn value drop done")
    
    # sort the dataframe based on serial_number and date
    model_1 = model_1.sort_values(['serial_number', 'date'], ascending=[True, True])
    print("sort done")
    return model_1

# %%
# cleaned data
cleaned_data = data_cleaning(model_name)
export_filename = model_name+".csv"
cleaned_data.to_csv(export_filename, index = False)
print("export complete")
# Out:
# initial column drop done
# initial row drop done
# repeating cloumn value drop done
# sort done

# %% [markdown]
# # Return only last one day data

# %%
last_day_data = cleaned_data.groupby('serial_number').tail(1)
export_filename = model_name+"_last_day.csv"
last_day_data.to_csv(export_filename, index = False)
